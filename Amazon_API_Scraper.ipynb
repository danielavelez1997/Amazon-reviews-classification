# %% [markdown]
# # Amazon API

# %%
import requests
from pprint import pprint

search = input('What do you want to search')

# Structure payload.
payload = {
    'source': 'amazon_search',
    'domain': 'com',
    'query': search,
    'start_page': 1,
    'pages': 6,
    'parse': True,
    'context': [
        {'key': 'category_id', 'value': 16391693031}
    ],
}

# Get response.
response = requests.request(
    'POST',
    'https://realtime.oxylabs.io/v1/queries',
    auth=('jnossa', 'yF3QT4vqS_MrB7'),
    json=payload,
)

# Print prettified response to stdout.
pprint(response.json())
# Out:
# {'job': {'_links': [{'href': 'http://data.oxylabs.io/v1/queries/7171834746551415809',
#                      'method': 'GET',
#                      'rel': 'self'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171834746551415809/results',
#                      'method': 'GET',
#                      'rel': 'results'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171834746551415809/results?type=raw',
#                      'method': 'GET',
#                      'rel': 'results-html'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171834746551415809/results?type=parsed',
#                      'method': 'GET',
#                      'rel': 'results-parsed'}],
#          'browser_instructions': None,
#          'callback_url': 'https://realtime.oxylabs.io:443/api/done',
#          'client_id': 49775,
#          'client_notes': None,
#          'content_encoding': 'utf-8',
#          'context': [{'key': 'force_headers', 'value': None},
#                      {'key': 'category_id', 'value': 16391693031},
#                      {'key': 'merchant_id', 'value': None},
#                      {'key': 'check_empty_geo', 'value': None},
#                      {'key': 'safe_search', 'value': True}],
#          'created_at': '2024-03-08 11:50:49',
#          'domain': 'com',
#          'geo_location': None,
#          'id': '7171834746551415809',
#          'limit': 10,
#          'locale': None,
#          'pages': 6,
#          'parse': True,
#          'parser_type': None,
#          'parsing_instructions': None,
#          'query': 'frying pan',
#          'render': None,
#          'session_info': None,
#          'source': 'amazon_search',
#          'start_page': 1,
#          'status': 'done',
#          'statuses': [],
#          'storage_type': None,
#          'storage_url': None,
#          'subdomain': 'www',
#          'updated_at': '2024-03-08 11:51:03',
#          'url': None,
#          'user_agent_type': 'desktop'},
#  'results': [{'content': {'page': 1,
#                           'pages': 1,
#                           'parse_status_code': 12000,
#                           'query': 'frying pan',
#                           'results': {'amazons_choices': [{'asin': 'B001AS13E8',
#                                                            'best_seller': False,
#                                                            'currency': 'USD',
#                                                            'is_amazons_choice': True,
#                                                            'is_prime': True,
#                                                            'is_sponsored': False,
#                                                            'manufacturer': '',
#                                                            'pos': 34,
#                                                            'price': 5.99,
#                                                            'price_upper': 5.99,
#                                                            'pricing_count': 1,
#                                                            'rating': 4.4,
#                                                            'reviews_count': 2774,
#                                                            'sales_volume': '2K+ '
#                                                                            'bought '
#                                                                            'in '
#                                                                            'past '
#                                                                            'month',
#                                                            'shipping_information': 'FREE '
#                                                                                    'delivery '
#                                                                                    'Thu, '
#                                                                                    'Mar '
#                                                                                    '14 '
#                                                                                    'on '
#                                                                                    '$35 '
#                                                                                    'of '
#                                                                                    'items '
#                                                                                    'shipped '
#                                                                                    'by '
#                                                                                    'AmazonOr '
#                                                                                    'fastest '
#                                                                                    'delivery '
#                                                                                    'Tue, '
#                                                                                    'Mar '
#                                                                                    '12',
#                                                            'title': 'IMUSA USA '
#                                                                     'Nonstick '
#                                                                     'Bistro '
#                                                                     'Saute Pan '
#                                                                     '8-Inch, '
#                                                                     'Black',
#                                                            'url': '/IMUSA-IMU-25008TGT-Nonstick-Bistro-8-Inch/dp/B001AS13E8/ref=sr_1_34?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-34',
#                                                            'url_image': 'https://m.media-amazon.com/images/I/51y4oZD8oqL._AC_UL320_.jpg'}],
#                                       'instant_recommendations': [],
#                                       'organic': [{'asin': 'B086PHS2V8',
#                                                    'best_seller': True,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 1,
#                                                    'price': 23.99,
#                                                    'price_strikethrough': 29.99,
#                                                    'price_upper': 23.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 17474,
#                                                    'sales_volume': '7K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'SENSARTE Nonstick '
#                                                             'Frying Pan '
#                                                             'Skillet, Swiss '
#                                                             'Granite Coating '
#                                                             'Omelette Pan, '
#                                                             'Healthy Stone '
#                                                             "Cookware Chef's "
#                                                             'Pan, PFOA Free '
#                                                             '(8/9.5/10/11/12.5 '
#                                                             'Inch) (9.5 Inch)',
#                                                    'url': '/SENSARTE-Nonstick-Frying-Pan-Skillet/dp/B086PHS2V8/ref=sr_1_1?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-1',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/61b-tqU2xoL._AC_UL320_.jpg'},
#                                                   {'asin': 'B009HBKQR0',
#                                                    'best_seller': True,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 2,
#                                                    'price': 27.19,
#                                                    'price_upper': 27.19,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 20747,
#                                                    'sales_volume': '10K+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Tramontina '
#                                                             'Professional Fry '
#                                                             'Pans (12-inch)',
#                                                    'url': '/Tramontina-80114-536DS-NSF-Certified-Professional/dp/B009HBKQR0/ref=sr_1_2?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-2',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/61k56NXC+WS._AC_UL320_.jpg'},
#                                                   {'asin': 'B08223PQFX',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 3,
#                                                    'price': 13.47,
#                                                    'price_strikethrough': 14.99,
#                                                    'price_upper': 13.47,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.4,
#                                                    'reviews_count': 38697,
#                                                    'sales_volume': '5K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Blue Diamond '
#                                                             'Cookware Diamond '
#                                                             'Infused Ceramic '
#                                                             'Nonstick 8" '
#                                                             'Frying Pan '
#                                                             'Skillet, '
#                                                             'PFAS-Free, '
#                                                             'Dishwasher Safe, '
#                                                             'Oven Safe, Blue',
#                                                    'url': '/Blue-Diamond-Ceramic-Nonstick-Frypan/dp/B08223PQFX/ref=sr_1_3?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-3',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71nWWM8lmzL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0732NXYNS',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 4,
#                                                    'price': 14.99,
#                                                    'price_strikethrough': 19.99,
#                                                    'price_upper': 14.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 34139,
#                                                    'sales_volume': '4K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'CAROTE Nonstick '
#                                                             'Frying Pan '
#                                                             'Skillet,Non Stick '
#                                                             'Granite Fry Pan '
#                                                             'Egg Pan Omelet '
#                                                             'Pans, Stone '
#                                                             "Cookware Chef's "
#                                                             'Pan, PFOA '
#                                                             'Free,Induction '
#                                                             'Compatible(Classic '
#                                                             'Granite, 8-Inch)',
#                                                    'url': '/Nonstick-Skillet-Cookware-Granite-Coating/dp/B0732NXYNS/ref=sr_1_4?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-4',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/61ETYCjbuuL._AC_UL320_.jpg'},
#                                                   {'asin': 'B073WFLD35',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 5,
#                                                    'price': 29.99,
#                                                    'price_strikethrough': 43.99,
#                                                    'price_upper': 29.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 10241,
#                                                    'sales_volume': '4K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Utopia Kitchen '
#                                                             'Nonstick Frying '
#                                                             'Pan Set - 3 Piece '
#                                                             'Induction Bottom '
#                                                             '- 8 Inches, 9.5 '
#                                                             'Inches and 11 '
#                                                             'Inches '
#                                                             '(Grey-Black)',
#                                                    'url': '/Utopia-Kitchen-Nonstick-Frying-Pan/dp/B073WFLD35/ref=sr_1_5?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-5',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/715z16LP+GL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07HHT8CQ4',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 6,
#                                                    'price': 19.83,
#                                                    'price_upper': 19.83,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.5,
#                                                    'reviews_count': 3610,
#                                                    'sales_volume': '900+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Farberware Glide '
#                                                             'Deep Nonstick '
#                                                             'Frying Pan / Fry '
#                                                             'Pan / Skillet '
#                                                             'with Helper '
#                                                             'Handle - 12.5 '
#                                                             'Inch, Black',
#                                                    'url': '/Farberware-10657-Aluminum-Skillet-Black/dp/B07HHT8CQ4/ref=sr_1_6?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-6',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71i2z7o1I0L._AC_UL320_.jpg'},
#                                                   {'asin': 'B073WF2JMD',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 7,
#                                                    'price': 9.99,
#                                                    'price_strikethrough': 14.99,
#                                                    'price_upper': 9.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 7164,
#                                                    'sales_volume': '700+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Utopia Kitchen '
#                                                             'Saute Fry Pan - '
#                                                             'Nonstick Frying '
#                                                             'Pan - 11 Inch '
#                                                             'Induction Bottom '
#                                                             '- Aluminum Alloy '
#                                                             'and Scratch '
#                                                             'Resistant Body - '
#                                                             'Riveted Handle '
#                                                             '(Grey-Black)',
#                                                    'url': '/Utopia-Kitchen-Inch-Nonstick-Frying/dp/B073WF2JMD/ref=sr_1_7?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-7',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71JoN9G2IsL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07Y91G6SC',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 8,
#                                                    'price': 14.99,
#                                                    'price_upper': 14.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.5,
#                                                    'reviews_count': 2878,
#                                                    'sales_volume': '1K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'GreenPan Rio '
#                                                             'Healthy Ceramic '
#                                                             'Nonstick 7" '
#                                                             'Frying Pan '
#                                                             'Skillet, '
#                                                             'PFAS-Free, '
#                                                             'Dishwasher Safe, '
#                                                             'Turquoise',
#                                                    'url': '/GreenPan-CC002478-001-Ceramic-Frying-Turquoise/dp/B07Y91G6SC/ref=sr_1_8?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-8',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/51inIOP3tBL._AC_UL320_.jpg'},
#                                                   {'asin': 'B096XC354Y',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 9,
#                                                    'price': 49.99,
#                                                    'price_strikethrough': 69.89,
#                                                    'price_upper': 49.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 1958,
#                                                    'sales_volume': '1K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'Or '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Vinchef Nonstick '
#                                                             'Deep Frying Pan '
#                                                             'Skillet with Lid, '
#                                                             '11in/5Qt Saute '
#                                                             'Pan, German 3C+ '
#                                                             'Ceramic Coating '
#                                                             'Technology, Heat '
#                                                             'Indicator, '
#                                                             'Induction '
#                                                             'Compatible',
#                                                    'url': '/Vinchef-Indicator-Induction-Compatible-Dishwasher/dp/B096XC354Y/ref=sr_1_9?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-9',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81nKy96T2qL._AC_UL320_.jpg'},
#                                                   {'asin': 'B018T909XG',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 10,
#                                                    'price': 19.99,
#                                                    'price_strikethrough': 29.99,
#                                                    'price_upper': 19.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.2,
#                                                    'reviews_count': 20957,
#                                                    'sales_volume': '800+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Gotham Steel 9.5 '
#                                                             'Inch Non Stick '
#                                                             'Frying Pans, '
#                                                             'Frying Pans '
#                                                             'Nonstick Skillet, '
#                                                             'Healthy and Non '
#                                                             'Toxic Ceramic Pan '
#                                                             'for Cooking, '
#                                                             'Nonstick Frying '
#                                                             'Pan, Oven Safe '
#                                                             'Skillet, '
#                                                             'Dishwasher Safe - '
#                                                             'Copper',
#                                                    'url': '/Nonstick-Durable-Ceramic-Coating-Cookware/dp/B018T909XG/ref=sr_1_10?dib=eyJ2IjoiMSJ9.IBl6VgQ7pF3422S9M53CXmwEogxz4nvaKkaXloERhozT4PGF07wlHXmwacqgwxwrg9vH_g2yxMx59qYgFnshvwf691pIWezZHjSlNEMgUK_hZvwUoFTFmLmQIPD6yyOrS49GTRORZFhEAhmq9ahmlVxX-_BYCit24eyBAxlCApuaIOaZnRoXf7X5noE_6sqs5Fn1StysZaej_MnasA1TU8JKMozt5zyMJ17VmQ3NGgyqrRZWwEYPXaNbvm9EovMag06WDpViMHHHCaZVnUo4ZGAj_vRtuD3Tqu3-o4Vymyc.DmGcChfMcsHCmg0MmetKkH3KPONHem3z3awx9j_AyJU&dib_tag=se&keywords=frying+pan&qid=1709898651&sr=8-10',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71N0ka6e26L._AC_UL320_.jpg'},
#                                                   {'asin': 'B07H18G2P4',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': False,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 11,
#                                                    'price': 34,
#                                                    'price_strikethrough': 60.99,
#                                                    'price_upper': 34,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 35604,
#                                                    'sales_volume': '2K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'Amazon.',
#                                                    'title': 'T-fal Ultimate '
#                                                             'Hard Anodized '
#                                                             'Nonstick Fry Pan '
#                                                             'Set 10, 12 Inch '
# ...
#                                                             'Free, Durable '
#                                                             'Bakelite Handle, '
#                                                             'Aluminum Alloy, '
#                                                             'Superior Omelet '
#                                                             'Pan Suitable for '
#                                                             'All Stove.',
#                                                    'url': '/Nonstick-Pan-Ceramic-Stone-Derived-Conductivity-Induction/dp/B07YDJXD6B/ref=sr_1_286?dib=eyJ2IjoiMSJ9.SXu3ewYP392_cChDfV8MPaUfQLFUi11RkdJ2B4HSzT4BgpQ9hRMleuiaNPQHkgYKv3OjMXqXmm1riQZ-SIBh6BCYwPWDGnQXdgilPSXHOFWf1-o35Z_wZ0I0bOyiAb87qevONQ7sfOeu8q3AKKVCZNO-qyNtEtIl4VNTk5Efh_5pdchX9kePR3ZAdpk1Mj0VMjSFwIilKsdk1rOFWwZCaY8rzTrvkUWt86zTnMMPX-23VBdDkjt-jBxl6dKfd-iSYuAJooxZP_BKJeq9eAVyUpnfnHHBzGV0MZ6bazGPdbU.exjaWVgrTEUtmXOH0KgQtH8jsEEaGHsChuRuSHZD_MQ&dib_tag=se&keywords=frying+pan&qid=1709898661&sr=8-286',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81NfHwMsJYL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0C5491GMT',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 47,
#                                                    'price': 49.99,
#                                                    'price_upper': 49.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 227,
#                                                    'sales_volume': '500+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'Or '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Sun, '
#                                                                            'Mar '
#                                                                            '10',
#                                                    'title': 'Ninja CW60030 '
#                                                             'NeverStick '
#                                                             'Comfort Grip 12" '
#                                                             'Fry Pan, '
#                                                             'Nonstick, '
#                                                             'Durable, Scratch '
#                                                             'Resistant, '
#                                                             'Dishwasher Safe, '
#                                                             'Oven Safe to '
#                                                             '400°F, Silicone '
#                                                             'Handles, Grey',
#                                                    'url': '/Ninja-CW60030-NeverStick-Resistant-Dishwasher/dp/B0C5491GMT/ref=sr_1_287?dib=eyJ2IjoiMSJ9.SXu3ewYP392_cChDfV8MPaUfQLFUi11RkdJ2B4HSzT4BgpQ9hRMleuiaNPQHkgYKv3OjMXqXmm1riQZ-SIBh6BCYwPWDGnQXdgilPSXHOFWf1-o35Z_wZ0I0bOyiAb87qevONQ7sfOeu8q3AKKVCZNO-qyNtEtIl4VNTk5Efh_5pdchX9kePR3ZAdpk1Mj0VMjSFwIilKsdk1rOFWwZCaY8rzTrvkUWt86zTnMMPX-23VBdDkjt-jBxl6dKfd-iSYuAJooxZP_BKJeq9eAVyUpnfnHHBzGV0MZ6bazGPdbU.exjaWVgrTEUtmXOH0KgQtH8jsEEaGHsChuRuSHZD_MQ&dib_tag=se&keywords=frying+pan&qid=1709898661&sr=8-287',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71SFMhfjFgL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0BF58HS4Y',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 48,
#                                                    'price': 15.99,
#                                                    'price_strikethrough': 16.99,
#                                                    'price_upper': 15.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.2,
#                                                    'reviews_count': 1442,
#                                                    'sales_volume': '200+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Thu, '
#                                                                            'Mar '
#                                                                            '14 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tomorrow, '
#                                                                            'Mar '
#                                                                            '9',
#                                                    'title': 'Four-Cup Fried '
#                                                             'Egg Pan, Medical '
#                                                             'Stone Non-Stick '
#                                                             'Frying Pan for '
#                                                             'Breakfast,Divided '
#                                                             'Egg Skillet '
#                                                             'Suitable for Gas '
#                                                             'Stove and '
#                                                             'Induction Cooker '
#                                                             '(3-inch eggs)',
#                                                    'url': '/MIUGO-Four-Cup-Non-Stick-Breakfast-Induction/dp/B0BF58HS4Y/ref=sr_1_288?dib=eyJ2IjoiMSJ9.SXu3ewYP392_cChDfV8MPaUfQLFUi11RkdJ2B4HSzT4BgpQ9hRMleuiaNPQHkgYKv3OjMXqXmm1riQZ-SIBh6BCYwPWDGnQXdgilPSXHOFWf1-o35Z_wZ0I0bOyiAb87qevONQ7sfOeu8q3AKKVCZNO-qyNtEtIl4VNTk5Efh_5pdchX9kePR3ZAdpk1Mj0VMjSFwIilKsdk1rOFWwZCaY8rzTrvkUWt86zTnMMPX-23VBdDkjt-jBxl6dKfd-iSYuAJooxZP_BKJeq9eAVyUpnfnHHBzGV0MZ6bazGPdbU.exjaWVgrTEUtmXOH0KgQtH8jsEEaGHsChuRuSHZD_MQ&dib_tag=se&keywords=frying+pan&qid=1709898661&sr=8-288',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/615MiP6x3mL._AC_UL320_.jpg'}],
#                                       'paid': [{'asin': 'B09ZKBS35G',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.8,
#                                                 'rel_pos': 1,
#                                                 'reviews_count': 17,
#                                                 'title': 'Hestan - ProBond '
#                                                          'Collection - TITUM '
#                                                          'Nonstick Triple '
#                                                          'Bonded Stainless '
#                                                          'Steel Skillets with '
#                                                          'Lids, Induction '
#                                                          'Cooktop Compatible, '
#                                                          'Made without PFOAs '
#                                                          '(8.5 & 11-inch)',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/RPC9cpe--OuUDTILtHLsGLIAAAGOHeb_lQEAAAH2AQBvbm9fdHhuX2JpZDcgICBvbm9fdHhuX2ltcDEgICAdYzn6/https://www.amazon.com/gp/aw/d/B09ZKBS35G/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3b520baa77213bd762b8ac1ee7cbee20&hsa_cr_id=0&qid=1709898661&sr=1-1-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_0_img&pd_rd_w=hzbh7&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=8Y561SVJNCKAVFKWK90Y&pd_rd_wg=hM8us&pd_rd_r=07692f2c-07b6-4508-a237-5c27fddf291f',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/81uHnYvvF-L._AC_SR180,120_QL70_.jpg'},
#                                                {'asin': 'B07K7B8HF7',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.2,
#                                                 'rel_pos': 2,
#                                                 'reviews_count': 115,
#                                                 'title': 'Hestan - NanoBond '
#                                                          'Collection - '
#                                                          'Titanium Stainless '
#                                                          'Steel 8.5-Inch '
#                                                          'Frying Pan - Toxin, '
#                                                          'PFAS, & Chemical '
#                                                          'Free Clean Cookware, '
#                                                          'Induction Cooktop '
#                                                          'Compatible',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/RPC9cpe--OuUDTILtHLsGLIAAAGOHeb_lQEAAAH2AQBvbm9fdHhuX2JpZDcgICBvbm9fdHhuX2ltcDEgICAdYzn6/https://www.amazon.com/gp/aw/d/B07K7B8HF7/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3b520baa77213bd762b8ac1ee7cbee20&hsa_cr_id=0&qid=1709898661&sr=1-2-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_1_img&pd_rd_w=hzbh7&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=8Y561SVJNCKAVFKWK90Y&pd_rd_wg=hM8us&pd_rd_r=07692f2c-07b6-4508-a237-5c27fddf291f',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/61siwKNlYEL._AC_SR180,120_QL70_.jpg'},
#                                                {'asin': 'B08KZ76KSV',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.2,
#                                                 'rel_pos': 3,
#                                                 'reviews_count': 49,
#                                                 'title': 'Hestan - CopperBond '
#                                                          'Collection - 100% '
#                                                          'Pure Copper Frying '
#                                                          'Pan, Induction '
#                                                          'Cooktop Compatible, '
#                                                          '11-Inch',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/RPC9cpe--OuUDTILtHLsGLIAAAGOHeb_lQEAAAH2AQBvbm9fdHhuX2JpZDcgICBvbm9fdHhuX2ltcDEgICAdYzn6/https://www.amazon.com/gp/aw/d/B08KZ76KSV/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=3b520baa77213bd762b8ac1ee7cbee20&hsa_cr_id=0&qid=1709898661&sr=1-3-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_2_img&pd_rd_w=hzbh7&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=8Y561SVJNCKAVFKWK90Y&pd_rd_wg=hM8us&pd_rd_r=07692f2c-07b6-4508-a237-5c27fddf291f',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/71My5BSB51L._AC_SR180,120_QL70_.jpg'}],
#                                       'suggested': []},
#                           'total_results_count': 60000,
#                           'url': 'https://www.amazon.com/s?k=frying '
#                                  'pan&page=6&rh=n:16391693031'},
#               'created_at': '2024-03-08 11:50:49',
#               'job_id': '7171834746551415809',
#               'page': 6,
#               'parser_type': '',
#               'status_code': 200,
#               'updated_at': '2024-03-08 11:51:03',
#               'url': 'https://www.amazon.com/s?k=frying%20pan&page=6&rh=n:16391693031'}]}

# %%
import pandas as pd

# Extract JSON content
json_content = response.json()

attributes = ['asin', 'is_amazons_choice', 'is_sponsored', 'best_seller', 'manufacturer', 'pos', 'price', 'rating', 'reviews_count', 'title', 'url', 'page_nbr', 'subgroup']

data = []
for page in json_content['results']:
    page_nbr = page['content']['page']
    for subgroup in page['content']['results']:

        if subgroup == 'paid': 
            # Extract ASINs from the list of dictionaries
            asin_list = [item['asin'] for item in page['content']['results'][subgroup]]
            is_amazons_choice_list = [item['is_amazons_choice'] for item in page['content']['results'][subgroup]]
            is_sponsored_list = [item['is_sponsored'] for item in page['content']['results'][subgroup]]
            best_seller_list = [item['best_seller'] for item in page['content']['results'][subgroup]]
            manufacturer_list = [item['manufacturer'] for item in page['content']['results'][subgroup]]
            pos_list = [item['rel_pos'] for item in page['content']['results'][subgroup]]
            price_list = [pd.NA] * len(asin_list)
            rating_list = [item['rating'] for item in page['content']['results'][subgroup]]
            reviews_count_list = [item['reviews_count'] for item in page['content']['results'][subgroup]]
            title_list = [item['title'] for item in page['content']['results'][subgroup]]
            url_list = [item['url'] for item in page['content']['results'][subgroup]]

        else:
            # Extract ASINs from the list of dictionaries
            asin_list = [item['asin'] for item in page['content']['results'][subgroup]]
            is_amazons_choice_list = [item['is_amazons_choice'] for item in page['content']['results'][subgroup]]
            is_sponsored_list = [item['is_sponsored'] for item in page['content']['results'][subgroup]]
            best_seller_list = [item['best_seller'] for item in page['content']['results'][subgroup]]
            manufacturer_list = [item['manufacturer'] for item in page['content']['results'][subgroup]]
            pos_list = [item['pos'] for item in page['content']['results'][subgroup]]
            price_list = [item['price'] for item in page['content']['results'][subgroup]]
            rating_list = [item['rating'] for item in page['content']['results'][subgroup]]
            reviews_count_list = [item['reviews_count'] for item in page['content']['results'][subgroup]]
            title_list = [item['title'] for item in page['content']['results'][subgroup]]
            url_list = [item['url'] for item in page['content']['results'][subgroup]]

        for i in range(len(asin_list)):
            row = {
                'asin': asin_list[i],
                'is_amazons_choice': is_amazons_choice_list[i],
                'is_sponsored': is_sponsored_list[i],
                'best_seller': best_seller_list[i],
                'manufacturer': manufacturer_list[i],
                'pos': pos_list[i],
                'price': price_list[i],
                'rating': rating_list[i],
                'reviews_count': reviews_count_list[i],
                'title': title_list[i],
                'url': url_list[i],
                'page_nbr': page_nbr,
                'subgroup': subgroup
            }
            data.append(row)

df = pd.DataFrame(data, columns=attributes)
df
# Out:
#            asin  is_amazons_choice  is_sponsored  best_seller manufacturer  \
# 0    B09ZKBS35G              False          True        False
# 1    B07K7B8HF7              False          True        False
# 2    B08KZ76KSV              False          True        False
# 3    B086PHS2V8              False         False         True
# 4    B009HBKQR0              False         False         True
# ..          ...                ...           ...          ...          ...
# 301  B0C22W37JT              False         False        False
# 302  B0BFGCJDQ9              False         False        False
# 303  B07YDJXD6B              False         False        False
# 304  B0C5491GMT              False         False        False
# 305  B0BF58HS4Y              False         False        False
#
#      pos  price  rating  reviews_count  \
# 0      1   <NA>     4.8             17
# 1      2   <NA>     4.2            115
# 2      3   <NA>     4.2             49
# 3      1  23.99     4.6          17474
# 4      2  27.19     4.6          20747
# ..   ...    ...     ...            ...
# 301   44  22.99     4.4            337
# 302   45   24.9     4.8            493
# 303   46  28.99     4.6           5587
# 304   47  49.99     4.6            227
# 305   48  15.99     4.2           1442
#
#                                                  title  \
# 0    Hestan - ProBond Collection - TITUM Nonstick T...
# 1    Hestan - NanoBond Collection - Titanium Stainl...
# 2    Hestan - CopperBond Collection - 100% Pure Cop...
# 3    SENSARTE Nonstick Frying Pan Skillet, Swiss Gr...
# 4           Tramontina Professional Fry Pans (12-inch)
# ..                                                 ...
# 301  3 QT Tri-Ply Stainless Steel Non-stick Sauté P...
# 302                 Lodge Yellowstone - 10.25" Skillet
# 303  CSK 10" Red Frying Pan-Non-Stick Skillets with...
# 304  Ninja CW60030 NeverStick Comfort Grip 12" Fry ...
# 305  Four-Cup Fried Egg Pan, Medical Stone Non-Stic...
#
#                                                    url  page_nbr subgroup
# 0    https://aax-us-iad.amazon.com/x/c/RCb4bwjTZgr0...         1     paid
# 1    https://aax-us-iad.amazon.com/x/c/RCb4bwjTZgr0...         1     paid
# 2    https://aax-us-iad.amazon.com/x/c/RCb4bwjTZgr0...         1     paid
# 3    /SENSARTE-Nonstick-Frying-Pan-Skillet/dp/B086P...         1  organic
# 4    /Tramontina-80114-536DS-NSF-Certified-Professi...         1  organic
# ..                                                 ...       ...      ...
# 301  /LOLYKITCH-Stainless-Non-stick-Induction-Dishw...         6  organic
# 302  /Lodge-Miniature-Skillet-Yellowstone-10-25/dp/...         6  organic
# 303  /Nonstick-Pan-Ceramic-Stone-Derived-Conductivi...         6  organic
# 304  /Ninja-CW60030-NeverStick-Resistant-Dishwasher...         6  organic
# 305  /MIUGO-Four-Cup-Non-Stick-Breakfast-Induction/...         6  organic
#
# [306 rows x 13 columns]

# %%
product_list = df['asin'].tolist()

for product in product_list:
    # Structure payload.
    payload = {
        'source': 'amazon_reviews',
        'domain': 'com',
        'query': product,
        'parse': True,
    }

    # Get response.
    response_reviews = requests.request(
        'POST',
        'https://realtime.oxylabs.io/v1/queries',
        auth=('jnossa', 'yF3QT4vqS_MrB7'),
        json=payload,
    )
    # Extract JSON content
    json_reviews = response_reviews.json()

    attributes = ['title', 'author', 'rating', 'content', 'timestamp', 'is_verified']

    data = []
    # Extract titles from the list of dictionaries
    title_list = [item['title'] for item in json_reviews['results'][0]['content']['reviews']]
    author_list = [item['author'] for item in json_reviews['results'][0]['content']['reviews']]
    rating_list = [item['rating'] for item in json_reviews['results'][0]['content']['reviews']]
    content_list = [item['content'] for item in json_reviews['results'][0]['content']['reviews']]
    timestamp_list = [item['timestamp'] for item in json_reviews['results'][0]['content']['reviews']]
    is_verified_list = [item['is_verified'] for item in json_reviews['results'][0]['content']['reviews']]

    for i in range(len(title_list)):
        row = {
            'title': title_list[i],
            'author': author_list[i],
            'rating': rating_list[i],
            'content': content_list[i],
            'timestamp': timestamp_list[i],
            'is_verified': is_verified_list[i]
        }
        data.append(row)

    df_reviews = pd.DataFrame(data, columns=attributes)

    # Locate the row based on the ID value
    index_to_update = df.loc[df['asin'] == product].index
    result_dict = df_reviews.to_dict(orient='records')

    # Update the 'review' feature for the located row
    df.loc[index_to_update, 'reviews'] = str(result_dict)

safe_search = search.replace(' ', '_')
df.to_csv(f'{safe_search}.csv')
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_22624\3391220225.py:51: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[{'title': '5.0 out of 5 stars I absolutely love these pans!', 'author': 'Brandy', 'rating': 5, 'content': 'I absolutely love these pans! They are very well made, contain no forever chemicals (PFAO/PFAS), very easy to clean, and cook evenly. The 12 inch pan is much larger than you think as the sides allow for more surface area comapred to traditional pans. They are well worth the money and belive Hestan has a life time guarentee on their pans which means the cost upfront will save you in the end!', 'timestamp': 'Reviewed in the United States October 7, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars A joy to use', 'author': 'George K', 'rating': 5, 'content': "These skillets are totally worth their price - I already own a non-nonstick Hestan and loved its looks and how easy it was to clean, but after doing my research and having had enough with 'high quality' non-stick pans from Calphalon and Zwilling, I decided to splurge for this set (it's actually a steal, compared to the price you'd pay if you were to buy two individual Hestans). I'll say they are truly a joy to use. They heat evenly, the surface has just the right amount of roughness to sear, but still after 4 months use, they still maintain their excellent non-stick ability (unlike their supposedly high end competitors). They can also take some abuse: No special instructions for what temperatures they need to be before you can wet/wash them, and they are perfectly fine in the dishwasher. Add these features to their looks, and you'll have a skillet set you'll want to use everyday. Totally worth their price.", 'timestamp': 'Reviewed in the United States July 17, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Excellent brand overall', 'author': 'Reagan S.', 'rating': 5, 'content': "I have several pieces of Hestan cookware.. Titum non stick, Nano Bond, and 3 ply stainless - also some with lids. I love LOVE these products.The quality and workmanship is outstanding, the different choices of pots and pans provides a great selection to suit almost every need. I have spoken to the concierge for help and he was really good at explaining and giving direction. This brand is expensive but I have found deals and specials on almost every item and the value is great based on quality and my overall satisfaction of performance. I have other cookware that simply will NOT clean up but this line looks like new even after many uses. I look forward to expanding my collection as needed. Very Very happy with every item I've bought and will recommend to anyone interested and will buy again !", 'timestamp': 'Reviewed in the United States April 12, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Great value for good quality fry pans!', 'author': 'Spook74', 'rating': 5, 'content': 'Good heat distribution, but it is SUPER at ease of cleaning! These are some good pans! We still do use a pat of butter sometimes to slicken it up a bit, but it will even fry eggs, etc., just as it is!We saw the comments that the handle can get hot, so we added a Lodge silicone hot handle holder (https://www.amazon.com/dp/B00C61O4ZI?ref=ppx_yo2ov_dt_b_product_details&th=1), which fits snug and still lets you hand it up by the hole in the handle.Great pan!', 'timestamp': 'Reviewed in the United States July 16, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Super well constructed', 'author': 'Doug Walker', 'rating': 5, 'content': 'I really appreciate the flush rivets as the pan is easier to keep clean.', 'timestamp': 'Reviewed in the United States December 26, 2022', 'is_verified': True}, {'title': '5.0 out of 5 stars Great deal on great pans', 'author': 'Dean Eric', 'rating': 5, 'content': 'We love these as safe from harmful chemicals and they go into the oven, deal on Amazon extraordinaire!', 't ...
#   df.loc[index_to_update, 'reviews'] = str(result_dict)

# %% [markdown]
# # Amazon Scrapping

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from datetime import datetime

HEADERS = {
    'authority': 'www.amazon.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="102", "Google Chrome";v="102"',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36'
}

# %%
# Function to extract Product Title
def get_title(soup):

    try:
        # Outer Tag Object
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner NavigatableString Object
        title_value = title.text

        # Title as a string value
        title_string = title_value.strip()

    except AttributeError:
        title_string = ""

    return title_string

# Function to extract Product Price
def get_price(soup):

    try:
        price = soup.find("span", attrs={'class':'aok-offscreen'}).string

    except AttributeError:

        try:
            # If there is some deal price
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()

        except:
            price = ""

    return price

# Function to extract Product Rating
def get_rating(soup):

    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
    
    except AttributeError:
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = ""	

    return rating

# Function to extract Number of User Reviews
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()

    except AttributeError:
        review_count = ""	

    return review_count

# Function to extract Availability Status
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()

    except AttributeError:
        available = "Not Available"	

    return available

def get_description(soup):
    try:
        available = soup.find('div', class_='a-expander-content a-expander-partial-collapse-content').text

    except AttributeError:
        available = "Not Available"	

    return available

def get_review_link(soup):
    try:
        a_tag = soup.find('a', class_='a-link-emphasis a-text-bold')
        available = 'https://www.amazon.com' + a_tag.get('href')

    except AttributeError:
        available = "Not Available"	

    return available

def get_sponsered_brand(soup):
    try:
        span_element = soup.find('span', class_='a-color-base')
        if span_element is not None:
            amazon_sponsored = span_element.text.strip()
        else:
            amazon_sponsored = ""
    except AttributeError:
        amazon_sponsored = ""
    
    return amazon_sponsored

# %%
# Extra Data as Html object from amazon Review page
def reviewsHtml(url, len_page):
    
    # Empty List define to store all pages html data
    soups = []
    # Request make for each page
    response = requests.get(url, headers=HEADERS)
    
    # Save Html object by using BeautifulSoup4 and lxml parser
    soup = BeautifulSoup(response.text, 'lxml')
    # Add single Html page data in master soups list
    soups.append(soup)
    # Loop for gather all 3000 reviews from 300 pages via range
    for page_no in range(1, len_page + 1):

        url = url + f'&page_number{page_no+1}'
        # parameter set as page no to the requests body
        params = {
            'ie': 'UTF8',
            'reviewerType': 'all_reviews',
            'filterByStar': 'critical',
            'pageNumber': page_no,
        }
        try:
            # Request make for each page
            response = requests.get(url, headers=HEADERS)
            
            # Save Html object by using BeautifulSoup4 and lxml parser
            soup = BeautifulSoup(response.text, 'lxml')

            # Add single Html page data in master soups list
            soups.append(soup)
        except: break
        
    return soups

# %%
# Grab Reviews name, description, date, stars, title from HTML
def getReviews(html_data):

    # Create Empty list to Hold all data
    data_dicts = []
    
    # Select all Reviews BOX html using css selector
    boxes = html_data.select('div[data-hook="review"]')
    
    # Iterate all Reviews BOX 
    for box in boxes:
        
        # Select Name using css selector and cleaning text using strip()
        # If Value is empty define value with 'N/A' for all.
        try:
            name = box.select_one('[class="a-profile-name"]').text.strip()
        except Exception as e:
            name = 'N/A'

        try:
            stars = box.select_one('[data-hook="review-star-rating"]').text.strip().split(' out')[0]
        except Exception as e:
            stars = 'N/A'   

        try:
            title = box.select_one('[data-hook="review-title"]').text.strip()
        except Exception as e:
            title = 'N/A'

        try:
            # Convert date str to dd/mm/yyy format
            datetime_str = box.select_one('[data-hook="review-date"]').text.strip().split(' on ')[-1]
            date = datetime.strptime(datetime_str, '%B %d, %Y').strftime("%d/%m/%Y")
        except Exception as e:
            date = 'N/A'

        try:
            description = box.select_one('[data-hook="review-body"]').text.strip()
        except Exception as e:
            description = 'N/A'

        try:
            verified = box.select_one('[data-hook="avp-badge"]').text.strip()
        except Exception as e:
            verified = 'N/A'

        # create Dictionary with al review data 
        data_dict = {
            'Name' : name,
            'Stars' : stars,
            'Title' : title,
            'Date' : date,
            'Description' : description,
            'Verified' : verified
        }

        # Add Dictionary in master empty List
        data_dicts.append(data_dict)
    
    return data_dicts

# %%
def get_all_reviews(reviews_url):
    len_page = 2

    try:
        # Grab all HTML
        html_datas = reviewsHtml(reviews_url, len_page)

        # Empty List to Hold all reviews data
        reviews = []

        # Iterate all Html page 
        for html_data in html_datas:
            
            # Grab review data
            review = getReviews(html_data)
            
            # add review data in reviews empty list
            reviews += review

    except: reviews = 'Not Available'

    return reviews

# %%
if __name__ == '__main__':

    # add your user agent 
    HEADERS = ({'User-Agent':'Mozilla/4.0 (compatible; MSIE 6.0; MSIE 5.5; Windows NT 5.0) Opera 7.03 [en]', 'Accept-Language': 'en-US, en;q=0.5'})

    # The base webpage URL
    URL = "https://www.amazon.com/s?k="

    # Get user input for the search query
    search = input("What do you want to search on Amazon? ")
    search = search.replace(" ", "+")
    
    # Combine the base URL with the modified search query
    URL = URL + search
    
    # HTTP Request
    webpage = requests.get(URL, headers=HEADERS)

    # Soup Object containing all data
    soup = BeautifulSoup(webpage.content, "html.parser")
    a_tag = soup.find('a', class_='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator')
    pages = []
    page = URL
    pages.append(page)
    more_pages = True
    while more_pages:
        try:
            # HTTP Request
            webpage = requests.get(page, headers=HEADERS)

            # Soup Object containing all data
            soup = BeautifulSoup(webpage.content, "html.parser")
            a_tag = soup.find('a', class_='s-pagination-item s-pagination-next s-pagination-button s-pagination-separator')
            page = 'https://www.amazon.com' + a_tag.get('href')
            pages.append(page)

        except: more_pages = False

    links = []
    for p in pages:
        # Fetch links as List of Tag Objects
        # links_page = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
        # sponsored = soup.find_all("span", attrs={'class':'a-color-secondary'})

        # HTTP Request
        webpage = requests.get(p, headers=HEADERS)

        # Soup Object containing all data
        soup = BeautifulSoup(webpage.content, "html.parser")

        links_page = soup.find_all("div", attrs={'class':'puis-card-container s-card-container s-overflow-hidden aok-relative puis-expand-height puis-include-content-margin puis puis-v36g8q2u37vpji29sg9uhoxaczm s-latency-cf-section puis-card-border'})
        links = links + links_page
    
    # Store the links
    links_list = []
    sponsored_list = []

    # Loop for extracting links from Tag Objects
    for link in links:
            link_element = link.find('a', class_='a-link-normal s-no-outline')
            links_list.append(link_element.get('href') if link_element else None)

            text_element = link.find('span', class_='a-color-secondary')
            sponsored_list.append(text_element.get_text(strip=True) if text_element else "Not Sponsored")

    d = {"title":[], "price":[], "rating":[], "num_reviews":[],"availability":[], "product_link":[], "description":[], "sponsored":[], "reviews_link":[], "reviews":[]}
    
    # Loop for extracting product details from each link 
    id = 0
    for link in links_list:
        product_link = "https://www.amazon.com" + link
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)

        new_soup = BeautifulSoup(new_webpage.content, "html.parser")

        # Function calls to display all necessary product information
        d['title'].append(get_title(new_soup))
        d['product_link'].append(product_link)
        d['price'].append(get_price(new_soup))
        d['rating'].append(get_rating(new_soup))
        d['num_reviews'].append(get_review_count(new_soup))
        d['availability'].append(get_availability(new_soup))
        d['description'].append(get_description(new_soup))
        d['sponsored'].append(sponsored_list[id])
        d['reviews_link'].append(get_review_link(new_soup))
        d['reviews'].append(get_all_reviews(get_review_link(new_soup)))
        id +=1

    amazon_df = pd.DataFrame.from_dict(d)
    amazon_df['title'].replace('', np.nan, inplace=True)
    amazon_df = amazon_df.dropna(subset=['title'])
    amazon_df.to_csv("amazon_data.csv", header=True, index=False)

# %%
pages
# Out:
# ['https://www.amazon.com/s?k=women+jacket']

# %%
# pd.set_option('display.max_rows', 20)

print(amazon_df.shape)
amazon_df.head(20)
# Out:
# (15, 10)
#                                                 title  \
# 0   Amazon Essentials Women's Lightweight Long-Sle...
# 1   MOERDENG Women's Waterproof Ski Jacket Warm Wi...
# 2   Vetinee Women’s Oversized Button Up Frayed Hem...
# 3   90 Degree By Reflex Women’s Lightweight, Full ...
# 7   Amazon Essentials Women's Lightweight Long-Sle...
# 10  THE NORTH FACE Teen Glacier Lightweight Full Z...
# 11  ECOWISH Women Cardigan Jacket Coat - Fall 2023...
# 12  SheKiss Womens Camouflage Shacket Jacket Coats...
# 13  CHICWISH Women's Classy Light Tan/Black Open F...
# 16               Columbia Women's Fast Trek Ii Jacket
# 18  Outdoor Ventures Women's Maryan Hooded Ultra L...
# 19  FARVALUE Women's Winter Coat Thicken Puffer Ja...
# 20    AI'MOURI Sherpa Fleece Outerwear Overcoat Women
# 21  Pepochic Womens Military Jacket Zip Up Snap Bu...
# 54  Dokotoo Womens Winter Quilted Jacket Stand Col...
#
#                                     price  \
# 0                                $24.50
# 1      $48.99 with 46 percent savings
# 2       $46.96 with 8 percent savings
# 3                                $39.99
# 7                         About this item
# 10     $36.00 with 39 percent savings
# 11                               $49.98
# 12                               $42.99
# 13     $49.90 with 29 percent savings
# 16                        About this item
# 18                        About this item
# 19     $59.99 with 14 percent savings
# 20     $39.95 with 33 percent savings
# 21                               $53.98
# 54                        About this item
#
#                                          rating     num_reviews  \
# 0                            4.5 out of 5 stars  20,589 ratings
# 1                            4.5 out of 5 stars  34,402 ratings
# 2                            4.2 out of 5 stars   2,450 ratings
# 3                            4.5 out of 5 stars   7,847 ratings
# 7                            4.5 out of 5 stars  20,589 ratings
# 10                           4.4 out of 5 stars     123 ratings
# 11                           4.2 out of 5 stars      30 ratings
# 12                           4.1 out of 5 stars   2,304 ratings
# 13                           4.1 out of 5 stars   3,822 ratings
# 16  Previous page of related Sponsored Products
# 18                           4.3 out of 5 stars   3,744 ratings
# 19                           4.2 out of 5 stars     577 ratings
# 20                           3.7 out of 5 stars   1,796 ratings
# 21                           4.1 out of 5 stars   2,736 ratings
# 54                           3.7 out of 5 stars      81 ratings
#
#                           availability  \
# 0                             In Stock
# 1                             In Stock
# 2                             In Stock
# 3                             In Stock
# 7                        Not Available
# 10                            In Stock
# 11                            In Stock
# 12                            In Stock
# 13                            In Stock
# 16                       Not Available
# 18                            In Stock
# 19  Only 5 left in stock - order soon.
# 20                            In Stock
# 21                            In Stock
# 54                       Not Available
#
#                                          product_link  \
# 0   https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 1   https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 2   https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 3   https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 7   https://www.amazon.com/Amazon-Essentials-Light...
# 10  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 11  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 12  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 13  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 16  https://www.amazon.com/Columbia-Womens-Jacket-...
# 18  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 19  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 20  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 21  https://www.amazon.com/sspa/click?ie=UTF8&spc=...
# 54  https://www.amazon.com/Dokotoo-Drawstring-Pock...
#
#                                           description  \
# 0     Product details    \nFabric type \n  \nShell...
# 1     Product details    \nFabric type \n  \n100% ...
# 2     Product details    \nFabric type \n  \n80% C...
# 3     Product details    \nFabric type \n  \n72% N...
# 7     Product details    \nFabric type \n  \nShell...
# 10    Product details    \nFabric type \n  \n100% ...
# 11    Product details    \nFabric type \n  \n100% ...
# 12    Product details    \nFabric type \n  \nMilit...
# 13    Product details    \nFabric type \n  \n100% ...
# 16    Product details    \nFabric type \n  \n100% ...
# 18    Product details    \nFabric type \n  \nShell...
# 19    Product details    \nFabric type \n  \nCotto...
# 20    Product details    \nFabric type \n  \nFleec...
# 21    Product details    \nFabric type \n  \nCotto...
# 54    Product details    \nFabric type \n  \n100% ...
#
#                       sponsored  \
# 0   Featured from Amazon brands
# 1                     Sponsored
# 2                     Sponsored
# 3                     Sponsored
# 7     100+ bought in past month
# 10                    Sponsored
# 11                    Sponsored
# 12                    Sponsored
# 13                    Sponsored
# 16     50+ bought in past month
# 18                    Sponsored
# 19                    Sponsored
# 20                    Sponsored
# 21                    Sponsored
# 54                Not Sponsored
#
#                                          reviews_link  \
# 0   https://www.amazon.com/Amazon-Essentials-Light...
# 1   https://www.amazon.com/MOERDENG-Waterproof-Mou...
# 2   https://www.amazon.com/Vetinee-Oversized-Boyfr...
# 3   https://www.amazon.com/90-Degree-Reflex-Brushe...
# 7   https://www.amazon.com/Amazon-Essentials-Light...
# 10  https://www.amazon.com/NORTH-FACE-Glacier-Ligh...
# 11  https://www.amazon.com/ECOWISH-Women-Cardigan-...
# 12  https://www.amazon.com/Military-Jackets-Camouf...
# 13  https://www.amazon.com/Chicwish-Womens-Classy-...
# 16  https://www.amazon.com/Columbia-Womens-Fast-Tr...
# 18  https://www.amazon.com/Outdoor-Ventures-Womens...
# 19  https://www.amazon.com/FARVALUE-Womens-Winter-...
# 20  https://www.amazon.com/Windproof-Outerwear-Fas...
# 21  https://www.amazon.com/Pepochic-Military-Butto...
# 54  https://www.amazon.com/Dokotoo-Quilted-Drawstr...
#
#                                               reviews
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 7                                                  []
# 10  [{'Name': 'The Review', 'Stars': '5.0', 'Title...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 16  [{'Name': 'SZ', 'Stars': '5.0', 'Title': '5.0 ...
# 18                                                 []
# 19                                                 []
# 20                                                 []
# 21                                                 []
# 54                                                 []

# %%
amazon_df.to_csv(f'amazon_data_{search}.csv')

# %%
import requests
from pprint import pprint

search = input('What do you want to search')

# Structure payload.
payload = {
    'source': 'amazon_search',
    'domain': 'com',
    'query': search,
    'start_page': 1,
    'pages': 6,
    'parse': True,
    'context': [
        {'key': 'category_id', 'value': 16391693031}
    ],
}

# Get response.
response = requests.request(
    'POST',
    'https://realtime.oxylabs.io/v1/queries',
    auth=('jnossa', 'yF3QT4vqS_MrB7'),
    json=payload,
)

# Print prettified response to stdout.
pprint(response.json())
# Out:
# {'job': {'_links': [{'href': 'http://data.oxylabs.io/v1/queries/7171795812823870465',
#                      'method': 'GET',
#                      'rel': 'self'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171795812823870465/results',
#                      'method': 'GET',
#                      'rel': 'results'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171795812823870465/results?type=raw',
#                      'method': 'GET',
#                      'rel': 'results-html'},
#                     {'href': 'http://data.oxylabs.io/v1/queries/7171795812823870465/results?type=parsed',
#                      'method': 'GET',
#                      'rel': 'results-parsed'}],
#          'browser_instructions': None,
#          'callback_url': 'https://realtime.oxylabs.io:443/api/done',
#          'client_id': 49775,
#          'client_notes': None,
#          'content_encoding': 'utf-8',
#          'context': [{'key': 'force_headers', 'value': None},
#                      {'key': 'category_id', 'value': 16391693031},
#                      {'key': 'merchant_id', 'value': None},
#                      {'key': 'check_empty_geo', 'value': None},
#                      {'key': 'safe_search', 'value': True}],
#          'created_at': '2024-03-08 09:16:07',
#          'domain': 'com',
#          'geo_location': None,
#          'id': '7171795812823870465',
#          'limit': 10,
#          'locale': None,
#          'pages': 6,
#          'parse': True,
#          'parser_type': None,
#          'parsing_instructions': None,
#          'query': 'hangers',
#          'render': None,
#          'session_info': None,
#          'source': 'amazon_search',
#          'start_page': 1,
#          'status': 'done',
#          'statuses': [],
#          'storage_type': None,
#          'storage_url': None,
#          'subdomain': 'www',
#          'updated_at': '2024-03-08 09:16:18',
#          'url': None,
#          'user_agent_type': 'desktop'},
#  'results': [{'content': {'page': 1,
#                           'pages': 1,
#                           'parse_status_code': 12000,
#                           'query': 'hangers',
#                           'results': {'amazons_choices': [{'asin': 'B071G5BSZV',
#                                                            'best_seller': False,
#                                                            'currency': 'USD',
#                                                            'is_amazons_choice': True,
#                                                            'is_prime': True,
#                                                            'is_sponsored': False,
#                                                            'manufacturer': '',
#                                                            'pos': 1,
#                                                            'price': 18.99,
#                                                            'price_strikethrough': 22.99,
#                                                            'price_upper': 18.99,
#                                                            'pricing_count': 1,
#                                                            'rating': 4.7,
#                                                            'reviews_count': 32461,
#                                                            'sales_volume': '10K+ '
#                                                                            'bought '
#                                                                            'in '
#                                                                            'past '
#                                                                            'month',
#                                                            'shipping_information': 'FREE '
#                                                                                    'delivery '
#                                                                                    'Wed, '
#                                                                                    'Mar '
#                                                                                    '13 '
#                                                                                    'on '
#                                                                                    '$35 '
#                                                                                    'of '
#                                                                                    'items '
#                                                                                    'shipped '
#                                                                                    'by '
#                                                                                    'AmazonOr '
#                                                                                    'fastest '
#                                                                                    'delivery '
#                                                                                    'Tue, '
#                                                                                    'Mar '
#                                                                                    '12',
#                                                            'title': 'Utopia '
#                                                                     'Home '
#                                                                     'Clothes '
#                                                                     'Hangers '
#                                                                     '50 Pack - '
#                                                                     'Plastic '
#                                                                     'Hangers '
#                                                                     'Space '
#                                                                     'Saving - '
#                                                                     'Durable '
#                                                                     'Coat '
#                                                                     'Hanger '
#                                                                     'with '
#                                                                     'Shoulder '
#                                                                     'Grooves '
#                                                                     '(Black)',
#                                                            'url': '/Utopia-Home-50-Pack-Plastic-Hangers/dp/B071G5BSZV/ref=sr_1_1?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-1',
#                                                            'url_image': 'https://m.media-amazon.com/images/I/71KJ5ooOeyL._AC_UL320_.jpg'}],
#                                       'instant_recommendations': [],
#                                       'organic': [{'asin': 'B07RDM1P5H',
#                                                    'best_seller': True,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 2,
#                                                    'price': 15.96,
#                                                    'price_strikethrough': 27.96,
#                                                    'price_upper': 15.96,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 34658,
#                                                    'sales_volume': '3K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Clothes Hangers '
#                                                             'Plastic 40 Pack - '
#                                                             'Black Plastic '
#                                                             'Hangers - Makes '
#                                                             'The Perfect Coat '
#                                                             'Hanger and '
#                                                             'General Space '
#                                                             'Saving Clothes '
#                                                             'Hangers for '
#                                                             'Closet - '
#                                                             'Percheros Ganchos '
#                                                             'para Colgar Ropa '
#                                                             'Hangars',
#                                                    'url': '/Neaterize-Plastic-Clothes-Lightweight-Available/dp/B07RDM1P5H/ref=sr_1_2?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-2',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71A6E+6tdVL._AC_UL320_.jpg'},
#                                                   {'asin': 'B01G3WS3PW',
#                                                    'best_seller': True,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 3,
#                                                    'price': 21.99,
#                                                    'price_strikethrough': 28.99,
#                                                    'price_upper': 21.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 32400,
#                                                    'sales_volume': '10K+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Utopia Home '
#                                                             'Premium Velvet '
#                                                             'Hangers 50 Pack - '
#                                                             'Non-Slip Clothes '
#                                                             'Hangers - Black '
#                                                             'Hangers - Suit '
#                                                             'Hangers with 360 '
#                                                             'Degree Rotatable '
#                                                             'Hook - Heavy Duty '
#                                                             'Coat Hangers',
#                                                    'url': '/Utopia-Home-Premium-Non-Slip-Hangers/dp/B01G3WS3PW/ref=sr_1_3?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-3',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81ZiBZZ6fCL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07GYLFFVR',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 4,
#                                                    'price': 23.99,
#                                                    'price_strikethrough': 37.99,
#                                                    'price_upper': 23.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 15851,
#                                                    'sales_volume': '10K+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'HOUSE DAY Black '
#                                                             'Velvet Hangers 60 '
#                                                             'Pack, Premium '
#                                                             'Clothes Non-Slip '
#                                                             'Felt Hangers, '
#                                                             'Sturdy Heavy Duty '
#                                                             'Coat Durable Suit '
#                                                             'for Space Saving, '
#                                                             'No Hanger Marks '
#                                                             '360 Rotating',
#                                                    'url': '/Hangers-Premium-Clothes-Non-Slip-Rotating/dp/B07GYLFFVR/ref=sr_1_4?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-4',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81dh3RTEn7L._AC_UL320_.jpg'},
#                                                   {'asin': 'B00FXNAAW2',
#                                                    'best_seller': True,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 5,
#                                                    'price': 26.28,
#                                                    'price_upper': 26.28,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.8,
#                                                    'reviews_count': 190656,
#                                                    'sales_volume': '10K+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Amazon Basics '
#                                                             'Slim, Velvet, '
#                                                             'Non-Slip Suit '
#                                                             'Clothes Hangers, '
#                                                             'Black/Silver - '
#                                                             'Pack of 50',
#                                                    'url': '/Amazon-Basics-Non-Slip-Clothes-Hangers/dp/B00FXNAAW2/ref=sr_1_5?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-5',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81Cn1+lUraL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07X24QMQM',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 6,
#                                                    'price': 19.99,
#                                                    'price_strikethrough': 24.19,
#                                                    'price_upper': 19.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 20107,
#                                                    'sales_volume': '5K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Utopia Home '
#                                                             'Plastic Hangers '
#                                                             '50 Pack - Clothes '
#                                                             'Hanger with Hooks '
#                                                             '- Durable & Space '
#                                                             'Saving Coat '
#                                                             'Hanger - Heavy '
#                                                             'Duty White '
#                                                             'Hangers - Skirt '
#                                                             'Hangers',
#                                                    'url': '/Utopia-Home-Plastic-Standard-Hangers/dp/B07X24QMQM/ref=sr_1_6?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-6',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71cS4Xc4ERL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07FP199PF',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 7,
#                                                    'price': 12.99,
#                                                    'price_strikethrough': 19.99,
#                                                    'price_upper': 12.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 36409,
#                                                    'sales_volume': '4K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Sharpty - Plastic '
#                                                             'Hangers - Adult '
#                                                             'Clothes Hangers - '
#                                                             'T-Shirt, Dress, '
#                                                             'Coat Hangers & '
#                                                             'Accessories - '
#                                                             'Heavy Duty '
#                                                             'Hangers - Notched '
#                                                             'Hanger, Durable & '
#                                                             'Versatile Color '
#                                                             'Clothing Closet '
#                                                             'Hanger(20-Pack,White)',
#                                                    'url': '/Sharpty-Plastic-Everyday-Standard-Clothing/dp/B07FP199PF/ref=sr_1_7?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-7',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71naMNm1qkL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0BM4QX8B5',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 8,
#                                                    'price': 29.99,
#                                                    'price_strikethrough': 38.71,
#                                                    'price_upper': 29.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 1330,
#                                                    'sales_volume': '6K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Utopia Home '
#                                                             'Premium Wooden '
#                                                             'Hangers 30 Pack - '
#                                                             'Durable & Slim '
#                                                             'Coat Hanger - '
#                                                             'Suit Hangers with '
#                                                             '360-Degree '
#                                                             'Rotatable Hook - '
#                                                             'Wood Hangers with '
#                                                             'Shoulder Grooves '
#                                                             '(Natural Color)',
#                                                    'url': '/Utopia-Home-Premium-Wooden-Hangers/dp/B0BM4QX8B5/ref=sr_1_8?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-8',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/81FZDgsddJL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0B2LLVCN7',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 9,
#                                                    'price': 14.99,
#                                                    'price_strikethrough': 19.35,
#                                                    'price_upper': 14.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 1746,
#                                                    'sales_volume': '2K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Utopia Home '
#                                                             'Clothes Hangers '
#                                                             '30 Pack - Plastic '
#                                                             'Hangers Space '
#                                                             'Saving - Durable '
#                                                             'Coat Hanger with '
#                                                             'Shoulder Grooves '
#                                                             '- Skirt Hangers - '
#                                                             '(White)',
#                                                    'url': '/Utopia-Home-Hangers-Pack-Plastic/dp/B0B2LLVCN7/ref=sr_1_9?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-9',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/715j6VoeEKL._AC_UL320_.jpg'},
#                                                   {'asin': 'B09RKG8YT9',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 10,
#                                                    'price': 15.99,
#                                                    'price_strikethrough': 19.99,
#                                                    'price_upper': 15.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.7,
#                                                    'reviews_count': 15267,
#                                                    'sales_volume': '1K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Utopia Home '
#                                                             'Premium Velvet '
#                                                             'Hangers 30 Pack - '
#                                                             'Non-Slip Clothes '
#                                                             'Hangers - Grey '
#                                                             'Hangers - Suit '
#                                                             'Hangers with 360 '
#                                                             'Degree Rotatable '
#                                                             'Hook - Heavy Duty '
#                                                             'Coat Hangers',
#                                                    'url': '/Utopia-Home-Premium-Velvet-Hangers/dp/B09RKG8YT9/ref=sr_1_10?dib=eyJ2IjoiMSJ9.Kwhuf0T9cr_CSGLKn-_c1z11Lf1BhG14z5MWrkkAqCQT_R3ibodh9TYT7jwNiJYLMS01EkjMU5KBs07dxdCnEmFQjMVleQrU1pMBpauYTh1PxHXPAZ91EFwNskBOgCAaKUfFq3PoE3bMIi1C3mx0TOnRqcmOTS6lVji_zPJRg7rfR1gcN77I-MsPaM5sgUiRroyIM7y3Tq-xGxizC-1vkEu_utsdPwMLuAFZGO79XfIhJZ16R49imLgXWxWsgR4JngVd-C0Xus3SJQCxor4IW_-CU_PlzFrOclezUR9JLjY.MXsyZWbIE7AFeAyx6p6HUQZt5ayPX2CXQuAoOYCfuvA&dib_tag=se&keywords=hangers&qid=1709889368&sr=8-10',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/812kO8QRVNL._AC_UL320_.jpg'},
#                                                   {'asin': 'B0BNHN4VY1',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 11,
#                                                    'price': 29.99,
#                                                    'price_upper': 29.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 1263,
#                                                    'sales_volume': '1K+ bought '
#                                                                    'in past '
#                                                                    'month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Heavy Duty '
#                                                             'Plastic Hangers '
#                                                             '50 Pack with '
#                                                             'Non-Slip '
#                                                             'Design,0.2 Inches '
#                                                             'Thick,360°Swivel '
#                                                             'Hook Space Saving '
#                                                             'Organizer for '
#                                                             'Bedroom '
#                                                             'Closet,Shirts,Pants,Strong '
#                                                             'Enough for Coat '
#                                                             '(Grey- S Shaped)',
# ...
#                                                             'Pants',
#                                                    'url': '/StorageWorks-Hangers-Shoulder-Natural-Jackets/dp/B0C9T98F1C/ref=sr_1_286?dib=eyJ2IjoiMSJ9.tOdzMniuaIjj4MOdg1Lw8pk4972TVi9HaUABlXji7QPqMdDGQiCaht2KJfLu8hWhrSuEGzysnCLJv8lUmWWJR89uee1oA504EQ4ZRODfMyKlTMPtwtY0KfXfewhvHg-GXvprDYom3pJ3eAIkTeyRG342kLgPARkYTtj5Dxu7d9Sftf1LxL5FhxfgDBl-vlrTymxRDdBEJvbq25Abbfh2vyl5YFT23x0as938YAhYuj2h-CVXL5HBihGFBmwNcWa33tUNopf3FtBESzx-oHCReNomDlGdOm6kELl1WPpG1pY.D_pT4c8Iz7GxciH4MpdsFfd2pS9rzJZsI5yD1-qGz5c&dib_tag=se&keywords=hangers&qid=1709889377&sr=8-286',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/6175ojXhMML._AC_UL320_.jpg'},
#                                                   {'asin': 'B0BZKDLQ2Y',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 47,
#                                                    'price': 29.99,
#                                                    'price_upper': 29.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 1064,
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'Cozymood Purple '
#                                                             'Velvet Hangers '
#                                                             'Felt Hangers 60 '
#                                                             'Pack, Thin '
#                                                             'Hangers Non Slip '
#                                                             'Clothes Hangers '
#                                                             'Velvet, Premium '
#                                                             'Flocked Hangers '
#                                                             'with 360 Degree '
#                                                             'Rotatable Hook, '
#                                                             'Durable Velvet '
#                                                             'Shirt Hangers for '
#                                                             'Adult',
#                                                    'url': '/Cozymood-Hangers-Felt-Clothes-Rotatable/dp/B0BZKDLQ2Y/ref=sr_1_287?dib=eyJ2IjoiMSJ9.tOdzMniuaIjj4MOdg1Lw8pk4972TVi9HaUABlXji7QPqMdDGQiCaht2KJfLu8hWhrSuEGzysnCLJv8lUmWWJR89uee1oA504EQ4ZRODfMyKlTMPtwtY0KfXfewhvHg-GXvprDYom3pJ3eAIkTeyRG342kLgPARkYTtj5Dxu7d9Sftf1LxL5FhxfgDBl-vlrTymxRDdBEJvbq25Abbfh2vyl5YFT23x0as938YAhYuj2h-CVXL5HBihGFBmwNcWa33tUNopf3FtBESzx-oHCReNomDlGdOm6kELl1WPpG1pY.D_pT4c8Iz7GxciH4MpdsFfd2pS9rzJZsI5yD1-qGz5c&dib_tag=se&keywords=hangers&qid=1709889377&sr=8-287',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/71C6Do7UsxL._AC_UL320_.jpg'},
#                                                   {'asin': 'B07F118PJT',
#                                                    'best_seller': False,
#                                                    'currency': 'USD',
#                                                    'is_amazons_choice': False,
#                                                    'is_prime': True,
#                                                    'is_sponsored': False,
#                                                    'manufacturer': '',
#                                                    'pos': 48,
#                                                    'price': 18.99,
#                                                    'price_upper': 18.99,
#                                                    'pricing_count': 1,
#                                                    'rating': 4.6,
#                                                    'reviews_count': 2094,
#                                                    'sales_volume': '100+ '
#                                                                    'bought in '
#                                                                    'past month',
#                                                    'shipping_information': 'FREE '
#                                                                            'delivery '
#                                                                            'Wed, '
#                                                                            'Mar '
#                                                                            '13 '
#                                                                            'on '
#                                                                            '$35 '
#                                                                            'of '
#                                                                            'items '
#                                                                            'shipped '
#                                                                            'by '
#                                                                            'AmazonOr '
#                                                                            'fastest '
#                                                                            'delivery '
#                                                                            'Tue, '
#                                                                            'Mar '
#                                                                            '12',
#                                                    'title': 'TOPIA HANGER '
#                                                             'Pants Hangers '
#                                                             'Space Saving, '
#                                                             '2-Pack Swing Arm '
#                                                             'Pants Organizer '
#                                                             'for Closet, '
#                                                             'Non-Slip Foam '
#                                                             'Padded Organizer '
#                                                             'Hanger for Multi '
#                                                             'Slacks, Jeans, '
#                                                             'Trousers, Skirts, '
#                                                             'Scarfs, '
#                                                             'Black-CT08B',
#                                                    'url': '/TOPIA-HANGER-Non-Slip-Organizer-Trousers/dp/B07F118PJT/ref=sr_1_288?dib=eyJ2IjoiMSJ9.tOdzMniuaIjj4MOdg1Lw8pk4972TVi9HaUABlXji7QPqMdDGQiCaht2KJfLu8hWhrSuEGzysnCLJv8lUmWWJR89uee1oA504EQ4ZRODfMyKlTMPtwtY0KfXfewhvHg-GXvprDYom3pJ3eAIkTeyRG342kLgPARkYTtj5Dxu7d9Sftf1LxL5FhxfgDBl-vlrTymxRDdBEJvbq25Abbfh2vyl5YFT23x0as938YAhYuj2h-CVXL5HBihGFBmwNcWa33tUNopf3FtBESzx-oHCReNomDlGdOm6kELl1WPpG1pY.D_pT4c8Iz7GxciH4MpdsFfd2pS9rzJZsI5yD1-qGz5c&dib_tag=se&keywords=hangers&qid=1709889377&sr=8-288',
#                                                    'url_image': 'https://m.media-amazon.com/images/I/610whXpnqgL._AC_UL320_.jpg'}],
#                                       'paid': [{'asin': 'B06Y2R5J2Q',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.6,
#                                                 'rel_pos': 1,
#                                                 'reviews_count': 78,
#                                                 'title': 'Koobay 16.5" Rose '
#                                                          'Gold Copper Clothes '
#                                                          'Hangers - 60 '
#                                                          'Pack,Heavy Duty '
#                                                          'Strong Metal Hanger '
#                                                          'for Storage Display '
#                                                          'Sling Organization '
#                                                          'of Coat Shirts '
#                                                          'Dresses Jacket '
#                                                          'Elegant Standard '
#                                                          'Suit Accessory',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/REx26z3N5S_WbRfx9k6OSeMAAAGOHVlU5gEAAAH2AQBvbm9fdHhuX2JpZDIgICBvbm9fdHhuX2ltcDEgICBeTlmK/https://www.amazon.com/gp/aw/d/B06Y2R5J2Q/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=01ba517321821305a7eaaac531b266f5&hsa_cr_id=5676931360301&qid=1709889377&sr=1-1-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_0_img&pd_rd_w=kSxpN&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=00AMXY4DRZRQQ75YQJKJ&pd_rd_wg=gwv8x&pd_rd_r=2d34b941-6c02-405d-b14b-fa52f69b8de5',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/71ykJeBVE4L._AC_SR180,120_QL70_.jpg'},
#                                                {'asin': 'B076M396J5',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.6,
#                                                 'rel_pos': 2,
#                                                 'reviews_count': 145,
#                                                 'title': '25Pack Koobay 16.5" '
#                                                          'Metal Hook Wire Rose '
#                                                          'Gold Copper Hangers '
#                                                          'with Clips Clothes '
#                                                          'Stroage Coat Hangers',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/REx26z3N5S_WbRfx9k6OSeMAAAGOHVlU5gEAAAH2AQBvbm9fdHhuX2JpZDIgICBvbm9fdHhuX2ltcDEgICBeTlmK/https://www.amazon.com/gp/aw/d/B076M396J5/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=01ba517321821305a7eaaac531b266f5&hsa_cr_id=5676931360301&qid=1709889377&sr=1-2-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_1_img&pd_rd_w=kSxpN&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=00AMXY4DRZRQQ75YQJKJ&pd_rd_wg=gwv8x&pd_rd_r=2d34b941-6c02-405d-b14b-fa52f69b8de5',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/81bYGoedIZL._AC_SR180,120_QL70_.jpg'},
#                                                {'asin': 'B06ZY941C9',
#                                                 'best_seller': False,
#                                                 'currency': 'USD',
#                                                 'is_amazons_choice': False,
#                                                 'is_sponsored': True,
#                                                 'manufacturer': '',
#                                                 'no_price_reason': 'unknown',
#                                                 'pricing_count': 1,
#                                                 'rating': 4.6,
#                                                 'rel_pos': 3,
#                                                 'reviews_count': 84,
#                                                 'title': '30Pack KOOBAY 13.7" '
#                                                          'Rose Gold Metal '
#                                                          'Heavy Duty Clips '
#                                                          'Pants Hangers '
#                                                          'Trousers with Swivel '
#                                                          'Hook',
#                                                 'url': 'https://aax-us-iad.amazon.com/x/c/REx26z3N5S_WbRfx9k6OSeMAAAGOHVlU5gEAAAH2AQBvbm9fdHhuX2JpZDIgICBvbm9fdHhuX2ltcDEgICBeTlmK/https://www.amazon.com/gp/aw/d/B06ZY941C9/?_encoding=UTF8&pd_rd_plhdr=t&aaxitk=01ba517321821305a7eaaac531b266f5&hsa_cr_id=5676931360301&qid=1709889377&sr=1-3-5aa29f2a-1490-4ae2-848e-815fb6406bcf&ref_=sbx_be_s_sparkle_mcd_asin_2_img&pd_rd_w=kSxpN&content-id=amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e:amzn1.sym.43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_p=43de8b42-cb89-4910-88e0-25fae4edd09e&pf_rd_r=00AMXY4DRZRQQ75YQJKJ&pd_rd_wg=gwv8x&pd_rd_r=2d34b941-6c02-405d-b14b-fa52f69b8de5',
#                                                 'url_image': 'https://m.media-amazon.com/images/I/71FdfaINtnL._AC_SR180,120_QL70_.jpg'}],
#                                       'suggested': []},
#                           'total_results_count': 100000,
#                           'url': 'https://www.amazon.com/s?k=hangers&page=6&rh=n:16391693031'},
#               'created_at': '2024-03-08 09:16:07',
#               'job_id': '7171795812823870465',
#               'page': 6,
#               'parser_type': '',
#               'status_code': 200,
#               'updated_at': '2024-03-08 09:16:18',
#               'url': 'https://www.amazon.com/s?k=hangers&page=6&rh=n%3A16391693031'}]}

# %%
import pandas as pd

# Extract JSON content
json_content = response.json()

attributes = ['asin', 'is_amazons_choice', 'is_sponsored', 'best_seller', 'manufacturer', 'pos', 'price', 'rating', 'reviews_count', 'title', 'url', 'page_nbr', 'subgroup']

data = []
for page in json_content['results']:
    page_nbr = page['content']['page']
    for subgroup in page['content']['results']:

        if subgroup == 'paid': 
            # Extract ASINs from the list of dictionaries
            asin_list = [item['asin'] for item in page['content']['results'][subgroup]]
            is_amazons_choice_list = [item['is_amazons_choice'] for item in page['content']['results'][subgroup]]
            is_sponsored_list = [item['is_sponsored'] for item in page['content']['results'][subgroup]]
            best_seller_list = [item['best_seller'] for item in page['content']['results'][subgroup]]
            manufacturer_list = [item['manufacturer'] for item in page['content']['results'][subgroup]]
            pos_list = [item['rel_pos'] if 'rel_pos' in item else item['pos'] for item in page['content']['results'][subgroup]]
            price_list = [pd.NA if 'rel_pos' in item else item['price'] for item in page['content']['results'][subgroup]]
            rating_list = [item['rating'] for item in page['content']['results'][subgroup]]
            reviews_count_list = [item['reviews_count'] for item in page['content']['results'][subgroup]]
            title_list = [item['title'] for item in page['content']['results'][subgroup]]
            url_list = [item['url'] for item in page['content']['results'][subgroup]]

        else:
            # Extract ASINs from the list of dictionaries
            asin_list = [item['asin'] for item in page['content']['results'][subgroup]]
            is_amazons_choice_list = [item['is_amazons_choice'] for item in page['content']['results'][subgroup]]
            is_sponsored_list = [item['is_sponsored'] for item in page['content']['results'][subgroup]]
            best_seller_list = [item['best_seller'] for item in page['content']['results'][subgroup]]
            manufacturer_list = [item['manufacturer'] for item in page['content']['results'][subgroup]]
            pos_list = [item['pos'] for item in page['content']['results'][subgroup]]
            price_list = [item['price'] for item in page['content']['results'][subgroup]]
            rating_list = [item['rating'] for item in page['content']['results'][subgroup]]
            reviews_count_list = [item['reviews_count'] for item in page['content']['results'][subgroup]]
            title_list = [item['title'] for item in page['content']['results'][subgroup]]
            url_list = [item['url'] for item in page['content']['results'][subgroup]]

        for i in range(len(asin_list)):
            row = {
                'asin': asin_list[i],
                'is_amazons_choice': is_amazons_choice_list[i],
                'is_sponsored': is_sponsored_list[i],
                'best_seller': best_seller_list[i],
                'manufacturer': manufacturer_list[i],
                'pos': pos_list[i],
                'price': price_list[i],
                'rating': rating_list[i],
                'reviews_count': reviews_count_list[i],
                'title': title_list[i],
                'url': url_list[i],
                'page_nbr': page_nbr,
                'subgroup': subgroup
            }
            data.append(row)

df = pd.DataFrame(data, columns=attributes)
print(df.shape)
df.head()
# Out:
# (306, 13)
#          asin  is_amazons_choice  is_sponsored  best_seller manufacturer  pos  \
# 0  B06Y2R5J2Q              False          True        False                 1
# 1  B076M396J5              False          True        False                 2
# 2  B06ZY941C9              False          True        False                 3
# 3  B07RDM1P5H              False         False         True                 2
# 4  B01G3WS3PW              False         False         True                 3
#
#    price  rating  reviews_count  \
# 0   <NA>     4.6             78
# 1   <NA>     4.6            145
# 2   <NA>     4.6             84
# 3  15.96     4.7          34658
# 4  21.99     4.7          32400
#
#                                                title  \
# 0  Koobay 16.5" Rose Gold Copper Clothes Hangers ...
# 1  25Pack Koobay 16.5" Metal Hook Wire Rose Gold ...
# 2  30Pack KOOBAY 13.7" Rose Gold Metal Heavy Duty...
# 3  Clothes Hangers Plastic 40 Pack - Black Plasti...
# 4  Utopia Home Premium Velvet Hangers 50 Pack - N...
#
#                                                  url  page_nbr subgroup
# 0  https://aax-us-iad.amazon.com/x/c/RMD39H3NPt8e...         1     paid
# 1  https://aax-us-iad.amazon.com/x/c/RMD39H3NPt8e...         1     paid
# 2  https://aax-us-iad.amazon.com/x/c/RMD39H3NPt8e...         1     paid
# 3  /Neaterize-Plastic-Clothes-Lightweight-Availab...         1  organic
# 4  /Utopia-Home-Premium-Non-Slip-Hangers/dp/B01G3...         1  organic

# %%
product_list = df['asin'].tolist()

for product in product_list:
    # Structure payload.
    payload = {
        'source': 'amazon_reviews',
        'domain': 'com',
        'query': product,
        'parse': True,
    }

    # Get response.
    response_reviews = requests.request(
        'POST',
        'https://realtime.oxylabs.io/v1/queries',
        auth=('jnossa', 'yF3QT4vqS_MrB7'),
        json=payload,
    )
    # Extract JSON content
    json_reviews = response_reviews.json()

    attributes = ['title', 'author', 'rating', 'content', 'timestamp', 'is_verified']

    data = []
    # Extract titles from the list of dictionaries
    title_list = [item['title'] for item in json_reviews['results'][0]['content']['reviews']]
    author_list = [item['author'] for item in json_reviews['results'][0]['content']['reviews']]
    rating_list = [item['rating'] for item in json_reviews['results'][0]['content']['reviews']]
    content_list = [item['content'] for item in json_reviews['results'][0]['content']['reviews']]
    timestamp_list = [item['timestamp'] for item in json_reviews['results'][0]['content']['reviews']]
    is_verified_list = [item['is_verified'] for item in json_reviews['results'][0]['content']['reviews']]

    for i in range(len(title_list)):
        row = {
            'title': title_list[i],
            'author': author_list[i],
            'rating': rating_list[i],
            'content': content_list[i],
            'timestamp': timestamp_list[i],
            'is_verified': is_verified_list[i]
        }
        data.append(row)

    df_reviews = pd.DataFrame(data, columns=attributes)

    # Locate the row based on the ID value
    index_to_update = df.loc[df['asin'] == product].index
    result_dict = df_reviews.to_dict(orient='records')

    # Update the 'review' feature for the located row
    df.loc[index_to_update, 'reviews'] = str(result_dict)

safe_search = search.replace(' ', '_')
df.to_csv(f'{safe_search}.csv')
# Out:
# C:\Users\jaoss\AppData\Local\Temp\ipykernel_174940\3391220225.py:51: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[{'title': '5.0 out of 5 stars Strong, slim, pretty.', 'author': 'Elizabeth', 'rating': 5, 'content': 'I love my new sturdy, slim hangers.I got the silver for my husband and rose color for myself. Got rid of all the old wire, clunky, bendable and breakable hangers. This helped me with space and organizing my closet. Worth the money.', 'timestamp': 'Reviewed in the United States February 15, 2024', 'is_verified': True}, {'title': '5.0 out of 5 stars Very Elegant and Sparkly! Very Satisfied', 'author': 'Crowwn Jewwels', 'rating': 5, 'content': 'These hangers are so elegant! I hv bought every single brand out there in this color to troubleshoot and these take the cake! They are very close to normal hanger size to not put an indent into the clothes on the end of the hanger! The indents in the hanger are nice and deep to keep clothes secure to the hanger! Because they are so thin you can squish so many more clothes into the closet! The most gorgeous color and the sparkle BIG TIME! I wish they had a version of this hanger without the indent for the clothes that dont need it but overall super amazing!', 'timestamp': 'Reviewed in the United States December 24, 2019', 'is_verified': True}, {'title': '5.0 out of 5 stars My favorite hanger', 'author': 'Beth A. Genicola', 'rating': 5, 'content': 'These are definitely by far my favorite hangers, metal hangers take up less room in your closet, and the deep pocket in the hanger allows for my spaghetti strap tops to hang without falling off the hanger.', 'timestamp': 'Reviewed in the United States December 23, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Nice looking and sturdy', 'author': 'Anne Pitzer', 'rating': 5, 'content': 'Nice little touch of flash in the closet', 'timestamp': 'Reviewed in the United States December 2, 2022', 'is_verified': True}, {'title': '5.0 out of 5 stars Best Coat Hangers in my lifetime!', 'author': 'Edwin H. Holmes Jr.', 'rating': 5, 'content': 'I bought a set from a local store, and loved them, and I have been looking for more for over a year. I found them on Amazon, as usual, at a great price, and I bought a case of them. They are the best hangers, at a great price.', 'timestamp': 'Reviewed in the United States May 29, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Glad I found these', 'author': 'kat', 'rating': 5, 'content': 'I bought copper hangers years ago and got frustrated with flocked hangers that are hard to get clothes on so very happy I found more. I bought a lot of them so much cheaper per hanger than smaller quantities.', 'timestamp': 'Reviewed in the United States June 25, 2023', 'is_verified': True}, {'title': '5.0 out of 5 stars Very disappointed. I only received 50 hangers not 60 as advertised!', 'author': 'nancy ryans', 'rating': 5, 'content': 'I didn’t receive the amount advertised. I received only 50 hangers opposed to the 60 I paid for', 'timestamp': 'Reviewed in the United States June 6, 2022', 'is_verified': True}, {'title': '5.0 out of 5 stars Definitely reccomend', 'author': 'Alexandria Finn', 'rating': 5, 'content': 'Very sturdy, great quality. They are a nice shiny copper color without looking metallic orange', 'timestamp': 'Reviewed in the United States June 23, 2018', 'is_verified': True}, {'title': '4.0 out of 5 stars Very nice', 'author': 'Nora stewart', 'rating': 4, 'content': 'I really love the look of these hangers and the type of metal that they are made out of. I wish there was a way to keep the clothes from slipping off of them and a way to make them so that the top swivels and then they would be perfect', 'timestamp': 'Reviewed in the United States July 5, 2022', 'is_verified': True}, {'title': '3.0 out of 5 stars Nice ...but', 'author': 'stenogrl', 'rating': 3, 'content': 'I love the hangers. However, the way they ...
#   df.loc[index_to_update, 'reviews'] = str(result_dict)

# %%
import tkinter as tk
from tkinter import messagebox

# Your script here

# Notify when the script is done
root = tk.Tk()
root.withdraw()  # Hide the main window

messagebox.showinfo("Notification", "Your script has finished running!")
# Out:
# 'ok'
